# %%
# load the necessary modules
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchAttributeException, WebDriverException

# initialize the chrome driver with selenium
driver = webdriver.Chrome(executable_path='/home/tk/Documents/chromedriver')

# %%
labels = [labels.rstrip('\n') for labels in open('key_words.txt')]
labels
# Out:
# ['ab coaster',
#  'ab crunch machine',
#  'ab roller',
#  'abdominal bench',
#  'air resistance exercise bike',
#  'ankle weight',
#  'arm curl machine',
#  'arm extension machine',
#  'back extension machine',
#  'barbell',
#  'battle rope',
#  'bench press',
#  'bench press machine',
#  'cable pulley machine',
#  'cables and pulley',
#  'calf machine',
#  'cruiser bike',
#  'dip station',
#  'dipping bar',
#  'dumbbell',
#  'e-z bar',
#  'elliptical machine',
#  'elliptical trainer',
#  'exercise bike',
#  'exercise resistance band',
#  'fixie bike',
#  'foam roller',
#  'hack squat',
#  'hack squat machine',
#  'hammer strength machine',
#  'handgrip exerciser',
#  'hyper extension bench',
#  'incline bench press',
#  'indoor cycle bike',
#  'inversion table',
#  'jump rope',
#  'kettlebell',
#  'lat pulldown machine',
#  'lateral raises machine',
#  'leg abduction machine',
#  'abduction machine',
#  'leg curl machine',
#  'leg extension machine',
#  'leg press machine',
# ...

# %%
len(labels)
# Out:
# 87

# %%
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

for i in labels[2:5]:
    arguments = {"keywords":i,"limit":1100,"print_urls":False, "format":"jpg", "size":"medium", "delay":5, 'chromedriver':"./chromedriver"}
    paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = ab roller
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.71OwLWK4jxL._SY355_.jpg
# Completed Image ====> 2.71%2BfjMwycAL._SX466_.jpg
# Completed Image ====> 3.811H-E5qABL._SX425_.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 4.Abdominal-Muscle-Sports-Abdominal-Trainer-Wheel-Exercises-AB-Roller-Workout-6-Pack-Strength-Training-AB-Wheel.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 5.UF_Ab_Wheel_Slide7_82917dc5-cccb-4239-9ba5-de35aa23965b_700x700.jpg
# Completed Image ====> 6.ab_wheel_cross_training_ab_roller_domyos_by_decathlon_8381582_1105390.jpg
# Completed Image ====> 7.71KK_2eQzgL._SL1500_1024x1024.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 8.51iALcl8d_2BL_spo_large.jpg
# Completed Image ====> 9.e9446849-943a-4049-8805-ec73a47da0ee_675x.progressive.jpg
# ...

# %%
for i in labels[5:10]:
    arguments = {"keywords":i,"limit":1100,"print_urls":False, "format":"jpg", "size":"medium", "delay":5, 'chromedriver':"./chromedriver"}
    paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = ankle weight
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.81rIgr0dW1L._SX425_.jpg
# Completed Image ====> 2.71qYe30aOWL._SX425_.jpg
# Completed Image ====> 3.51C7zN4l7GL._SX466_.jpg
# Completed Image ====> 4.7146k7-M1SL._SX425_.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 5.710U1jRtH5L._SY355_.jpg
# Completed Image ====> 6.Ankle_Weights_1_800x.jpg
# Completed Image ====> 7.814HepQNhcL._SX466_.jpg
# Completed Image ====> 8.a2zcare-ankle-weights-leg-weights-adjustable-ankle-weights-1lb-2lb-3lb-4lb-5lb-6lb-8lb-10lb-4-600x600.jpg
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 9.91zvV%2Bi6JOL._SX466_.jpg
# Completed Image ====> 10.s-l640.jpg
# Completed Image ====> 11.s-l640.jpg
# Completed Image ====> 12.81ekLG4mEwL._SX425_.jpg
# ...

# %%
for i in labels[10:20]:
    arguments = {"keywords":i,"limit":1100,"print_urls":False, "format":"jpg", "size":"medium", "delay":5, 'chromedriver':"./chromedriver"}
    paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = battle rope
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.blue-black-elitesrs-battle-rope-weightlifter_large.jpg
# Completed Image ====> 2.grey-black-battle-rope-workout-elitesrs-fitness_large.jpg
# Completed Image ====> 3.gettyimages-657495548-1527710829.jpg
# Completed Image ====> 4.71eKKwyjMML._SX425_.jpg
# Completed Image ====> 5.Get-Ripped-with-Battle-Ropes.jpg
# Completed Image ====> 6.battle-rope-workout-guide.jpg
# Completed Image ====> 7.cross_training_battle_rope_domyos_by_decathlon_8386445_1417749.jpg
# Completed Image ====> 8.battle-rope-15inch--thick-wrapped-800.jpg
# Completed Image ====> 9.42368977-1-f.jpg
# Completed Image ====> 10.accc1a3e-ac69-4318-86f1-75fa320637b5_675x.progressive.jpg
# Completed Image ====> 11.Green-Black-Battle-rope1_1024x1024.jpg
# Completed Image ====> 12.918Lvx4nAKL._SX466_.jpg
# ...

# %%
# removed image size filter 
for i in labels[15:20]:
    arguments = {"keywords":i,"limit":1100,"print_urls":False, "delay":3, 'chromedriver':"./chromedriver"}
    paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = calf machine
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.41uMBDYmP%2BL._SX342_.jpg
# Completed Image ====> 2.71uCsymyWXL._SY355_.jpg
# Completed Image ====> 3.HSISOPLplcalf-2.jpg
# Completed Image ====> 4.MDP-2003-Incline-Calf-Raise-copy-500x700.jpg
# Completed Image ====> 5.cyb-pl-seatedcalf-1_2.jpg
# Completed Image ====> 6.barbarian-commercial-calf-raise-machine-800x800.jpg
# Completed Image ====> 7.legpress_down.jpg
# Completed Image ====> 8.deltech-fitness-seated-calf-raise-machine-df805.png
# Completed Image ====> 9.41tnSTXl6ZL._SX425_.jpg
# Completed Image ====> 10.cc-5_1-mainweb-3500x3500.jpg
# Completed Image ====> 11.0000070_calf_550.jpeg
# Completed Image ====> 12.911sc-machine-calf-seated-tko__14773.1523358778.jpg
# Completed Image ====> 13.seated-calf-raise-machine-500x500.jpg
# ...
