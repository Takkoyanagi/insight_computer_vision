# %%
# load the necessary modules
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchAttributeException, WebDriverException
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

# initialize the chrome driver with selenium
driver = webdriver.Chrome(executable_path='/home/tk/Documents/chromedriver')

labels = [labels.rstrip('\n') for labels in open('key_words.txt')]
len(labels)
# Out:
# 79

# %%
from icrawler.builtin import BingImageCrawler, BaiduImageCrawler

for i in labels[:1]:
    bing_crawler = BingImageCrawler(downloader_threads=4,
                               storage={'root_dir':i})
    bing_crawler.crawl(keyword=i, max_num=2000)
# Out:
# 2019-09-15 14:35:19,867 - WARNING - icrawler.crawler - Due to Bing's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000
# 2019-09-15 14:35:19,868 - INFO - icrawler.crawler - start crawling...
# 2019-09-15 14:35:19,869 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2019-09-15 14:35:19,871 - INFO - icrawler.crawler - starting 1 parser threads...
# 2019-09-15 14:35:19,874 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2019-09-15 14:35:20,517 - INFO - parser - parsing result page https://www.bing.com/images/async?q=ab coaster&first=0
# 2019-09-15 14:35:20,594 - INFO - downloader - skip downloading file 000001.jpg
# 2019-09-15 14:35:20,595 - INFO - downloader - skip downloading file 000002.jpg
# 2019-09-15 14:35:20,597 - INFO - downloader - skip downloading file 000003.jpg
# 2019-09-15 14:35:20,598 - INFO - downloader - skip downloading file 000004.jpg
# ...

# %%
for i in labels[0:6]:
    baidu_crawler = BaiduImageCrawler(storage={'root_dir':i+str(1)})
    baidu_crawler.crawl(keyword=i, max_num=2000)

# %%
# load the necessary modules
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import NoSuchAttributeException, WebDriverException
from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()

# initialize the chrome driver with selenium
driver = webdriver.Chrome(executable_path='/home/tk/Documents/chromedriver')

labels = [labels.rstrip('\n') for labels in open('key_words.txt')]
# labels

# %%
for i in labels[45:50]:
    arguments = {"keywords":i,"limit":1100,"print_urls":False,"delay":3, 'chromedriver':"./chromedriver"}
    paths = response.download(arguments)

# %%
arguments = {"keywords":"bosu ball","limit":1100,"print_urls":False,"delay":3, 'chromedriver':"./chromedriver"}
paths = response.download(arguments)
# Out:
# Item no.: 1 --> Item name = bosu ball
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1.bosu-ball-1_2.jpg
# Completed Image ====> 2.50799e15-bf9a-4a5a-9f55-72ded3d853c8_1.bcc4f2377577bc840499413dae63130c.jpeg
# Completed Image ====> 3.large_dfcca233-df46-456f-a61f-a9d40d2034f0.jpg
# Completed Image ====> 4.bosu-ball-plank.jpg
# Completed Image ====> 5.41MZAXleHIL._SX425_.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 6.bosu-ball-squat.jpg
# Completed Image ====> 7.27106141316795p.jpg
# Completed Image ====> 8.71wvX8ppW1L._SL1500_.jpg
# Completed Image ====> 9.What-You-Dont-Know-About-BOSU-Balls.jpg
# Completed Image ====> 10.b9478a0a-a20e-4163-8083-da891e5be014_1.1ac70ec53d0a40c2a319316b8ff35e1c.jpeg
# Completed Image ====> 11.LS3570-BOSU-BALL2.jpg
# ...
